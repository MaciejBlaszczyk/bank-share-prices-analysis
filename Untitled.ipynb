# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
countries = ["USA.csv", "GERMANY.csv", "GREECE.csv", "BRASIL.csv", "SWISS.csv", "NETHERLANDS.csv"]

# %%
a = [1,2,3]
b = np.reshape(a, newshape=(-1,1))
c = np.reshape(b, newshape=(1,-1))

c[0]
# Out:
# array([1, 2, 3])

# %%
c
# Out:
# array([[1, 2, 3]])

# %%
def load_data(file_name, scaler):
    data = pd.read_csv("C:/Users/OPTIMUSPRIME/Desktop/Studia/Eksploracja danych/Project/" + file_name)
    data.fillna(0, inplace=True)
    print(data.columns)
    data_after_year = data.loc[data["Date"] > "2012-00-00"]
    bank_values = data_after_year.values[:,1]
    bank_values = np.reshape(scaler.fit_transform(np.reshape(bank_values, newshape=(-1,1))), newshape=(1,-1))[0]
    dates = [dt.datetime.strptime(d, '%Y-%m-%d').date() for d in data_after_year.values[:, 0]]
    return dates, bank_values

# %%
scalers = [StandardScaler(), RobustScaler(), MinMaxScaler()]
temp=1
for scaler in scalers:
    bal = plt.figure(figsize=(20,12))
    for country in countries:
        dates, bank_values = load_data(country, scaler)
        plt.plot(dates, bank_values)
        plt.grid()
        plt.legend(("DE BANK", "USA BANK", "GR_BANK", "BR_BANK", "SS_BANK", "NL_BANK"))
    bal.savefig("blalba" + str(temp) + ".png")
    temp = temp + 1
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
# ...
